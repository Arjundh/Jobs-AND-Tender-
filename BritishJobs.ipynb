# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
import re
import pandas as pd
import numpy as np

# %%
all_section = []
all_section1 = []
all_section2 = []
all_section3 = []
all_section4 = []
all_section5 = []
all_section6 = []
all_section7=[]
all_section8=[]
all_link1=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
list1 = ['UX']
         

for item in list1:
    category1 = item.split('\n')

    for index in range(1,7):
        url = "https://www.britishjobs.co.uk/search-jobs?category=&distance=15&fp=1&geo=&offset="+str(index)+"00&perpage=100&posted=&q="+item+"&salarymax=&salarymin=&salarytype=annum&search=1&tempperm=Any"
        driver.get(url)
        print(index)
    
        driver.implicitly_wait(10)
    
        section = driver.find_elements_by_xpath("//h2[@class='job__title']//a")
        section1 = driver.find_elements_by_xpath("//dd[@class='job__details-value location']")
        section2 = driver.find_elements_by_xpath("//p[@class='job__description noscript-show']")
        section3 = driver.find_elements_by_xpath("//dd[@class='job__details-value salary']")
        section4 = driver.find_elements_by_xpath("//dl[@class='job__details']")
        section5 = driver.find_elements_by_xpath("//dl[@class='job__details l-flex-row']")
        section6 = driver.find_elements_by_xpath("//dd[@class='job__details-value text--semibold']")
        section7 = driver.find_elements_by_xpath("//div[@class='job__main']")
        for i in section:
            all_section.append(i.text)
            all_link = i.get_attribute('href')
            all_link1.append(all_link)
        for i in section1:
            all_section1.append(i.text)
            all_section6.append(category1)
        for i in section2:
            all_section2.append(i.text)
        for i in section3:
            all_section3.append(i.text)
        for n in section4:
            all_section4.append(n.text)
        for q in section5:
            all_section5.append(q.text)
        for q in section6:
            all_section7.append(q.text)
        for q in section7:
            all_section8.append(q.text)
driver.close()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
all_section5[0]
# Out:
# 'Salary:\n£50,000 - £60,000/annum\nLocation:\nLondon\nJob Type:\nPermanent'

# %%
df=pd.DataFrame(index=range(0,(len(all_section5))),columns=['JobSalary'])
for idx,section in enumerate(all_section5):
    scn=section.split('\n')
    if('£' in scn[1]):     
        try:
            df.iloc[idx,0]=scn[1]
        except IndexError:
            df.iloc[idx,0]=np.nan

# %%
df['JobLocation']=pd.Series(all_section1)

# %%
df['JobDescription']=pd.Series(all_section2)

# %%
df['JobTitle']=pd.Series(all_section)

# %%
df['JobCompanyName']=pd.Series(all_section7)

# %%
df['JobUrl']=pd.Series(all_link1)

# %%
df['LogoUrl']="https://www.cv-library.co.uk/assets/images/cvdb/britishjobs-network-logo-4513ab5121d0fa993c824d91830786cd2f201cd9d1deb45d12cc61c6b72f7f13.png"

# %%
df1=df.dropna(thresh=4)

# %%
df1
# Out:
#                                              JobSalary  \
# 0                              £50,000 - £60,000/annum
# 1                                      £375 - £425/day
# 2                                      £350 - £380/day
# 3                                                  NaN
# 4                                 £25,000 - £30,000...
# 5                              £27,600 - £32,800/annum
# 6                                                  NaN
# 7                                                  NaN
# 8                                 £30,000 - £40,000...
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                             £50,000 - £75,000/annum
# 13                  £25,900 - £30,200/annum £26-35,000
# 14                                                 NaN
# 15          £40,000 - £55,000/annum Excellent Benefits
# ...

# %%
#df2=df1.drop_duplicates(subset=None,keep='first',inplace=False)

# %%
list1 = ['UI','CSS','ADOBE','PYTHON','JAVA','MAVEN','JAVASCRIPT','UX','GRAPHIC DESIGN', 'HTML','.NET', 'PHP', 'WEB DESIGN','lOGO DESIGN','PHOTOSHOP','ILLUSTOR','FRONT END','BACK END','ANIMATION','VFX']
list2 = []
list3 = []

# %%
ser = pd.Series(df['JobTitle']) 
ser = ser.apply(lambda x:x.upper())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-dc8996ca4255> in <module>
#       1 ser = pd.Series(df['JobTitle'])
# ----> 2 ser = ser.apply(lambda x:x.upper())
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-15-dc8996ca4255> in <lambda>(x)
#       1 ser = pd.Series(df['JobTitle'])
# ----> 2 ser = ser.apply(lambda x:x.upper())
#
# AttributeError: 'float' object has no attribute 'upper'

# %%
for items in ser:
    list2 = []
    #print(items)
    for i in list1:
        #print(i)
        if i in items:
            list2.append(i)
    print(list2)
    list3.append(list2)
# Out:
# ['UI', 'UX']
# ['UX']
# ['UI', 'UX']
# []
# []
# ['UX']
# ['UX']
# ['UI', 'UX']
# []
# []
# []
# ['UI', 'UX']
# ['UI', 'UX']
# ['UX']
# []
# []
# ['UI']
# ['UX']
# ['UX']
# ['UX']
# ['UX']
# []
# []
# []
# []
# []
# []
# []
# ['UX']
# ['UX']
# ['UX']
# []
# ['FRONT END']
# []
# ['UX']
# []
# []
# []
# []
# []
# []
# ['CSS', 'HTML', 'PHP']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['CSS', 'HTML']
# []
# []
# ['UI']
# []
# []
# []
# ['UI', 'UX']
# []
# []
# ['UI']
# []
# ['UI']
# []
# []
# []
# []
# []
# []
# ['UI']
# []
# []
# ['PHP']
# []
# []
# ['CSS', 'HTML', 'PHP']
# []
# ['UI']
# []
# []
# []
# []
# []
# []
# []
# []
# ['PHP']
# ['.NET']
# []
# []
# []
# []
# []
# []
# ['UI']
# []
# []
# []
# ['UI']
# []
# []
# []
# []
# []
# []
# ['PHP']
# ['.NET']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['HTML', 'PHP']
# []
# ['.NET']
# []
# []
# []
# []
# []
# ['.NET']
# []
# ['PHP']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['PHP']
# []
# []
# ...

# %%
df1['JobSkills'] = pd.Series(list3)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['JobSkills'] = df1['JobSkills'].apply(lambda x:' , '.join([str(elem) for elem in x]))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['JobSkills'].replace('', np.nan, inplace=True)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df1
# Out:
#                                              JobSalary  \
# 0                              £50,000 - £60,000/annum
# 1                                      £375 - £425/day
# 2                                      £350 - £380/day
# 3                                                  NaN
# 4                                 £25,000 - £30,000...
# 5                              £27,600 - £32,800/annum
# 6                                                  NaN
# 7                                                  NaN
# 8                                 £30,000 - £40,000...
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                             £50,000 - £75,000/annum
# 13                  £25,900 - £30,200/annum £26-35,000
# 14                                                 NaN
# 15          £40,000 - £55,000/annum Excellent Benefits
# ...

# %%
df2=df1.drop_duplicates()

# %%
df2['JobUrl'].value_counts(ascending=False)
# Out:
# https://www.britishjobs.co.uk/job/211047367/Full-Stack-Developer-PHP-Laravel-JavaScript-jQuery             2
# https://www.britishjobs.co.uk/job/211048774/Software-Developer-ASP-NET-MVC                                 2
# https://www.britishjobs.co.uk/job/211049250/Senior-JavaScript-Developer-Nottingham-6-Month-Contract        2
# https://www.britishjobs.co.uk/job/207848924/Lead-Nurse                                                     2
# https://www.britishjobs.co.uk/job/211050777/Frontend-Developer                                             2
# https://www.britishjobs.co.uk/job/211040211/Front-End-JavaScript-Developer                                 2
# https://www.britishjobs.co.uk/job/211044713/iOS-Developer                                                  2
# https://www.britishjobs.co.uk/job/211045926/Senior-Front-End-Developer                                     2
# https://www.britishjobs.co.uk/job/211044581/Front-End-Developer                                            2
# ...

# %%
df2['JobUrl'].nunique()
# Out:
# 588

# %%
df2['JobUrl'].value_counts(ascending=False)
# Out:
# https://www.britishjobs.co.uk/job/211047367/Full-Stack-Developer-PHP-Laravel-JavaScript-jQuery             2
# https://www.britishjobs.co.uk/job/211048774/Software-Developer-ASP-NET-MVC                                 2
# https://www.britishjobs.co.uk/job/211049250/Senior-JavaScript-Developer-Nottingham-6-Month-Contract        2
# https://www.britishjobs.co.uk/job/207848924/Lead-Nurse                                                     2
# https://www.britishjobs.co.uk/job/211050777/Frontend-Developer                                             2
# https://www.britishjobs.co.uk/job/211040211/Front-End-JavaScript-Developer                                 2
# https://www.britishjobs.co.uk/job/211044713/iOS-Developer                                                  2
# https://www.britishjobs.co.uk/job/211045926/Senior-Front-End-Developer                                     2
# https://www.britishjobs.co.uk/job/211044581/Front-End-Developer                                            2
# ...

# %%
valcnt=df2['JobUrl'].value_counts()

# %%
valcnt
# Out:
# https://www.britishjobs.co.uk/job/211047367/Full-Stack-Developer-PHP-Laravel-JavaScript-jQuery             2
# https://www.britishjobs.co.uk/job/211048774/Software-Developer-ASP-NET-MVC                                 2
# https://www.britishjobs.co.uk/job/211049250/Senior-JavaScript-Developer-Nottingham-6-Month-Contract        2
# https://www.britishjobs.co.uk/job/207848924/Lead-Nurse                                                     2
# https://www.britishjobs.co.uk/job/211050777/Frontend-Developer                                             2
# https://www.britishjobs.co.uk/job/211040211/Front-End-JavaScript-Developer                                 2
# https://www.britishjobs.co.uk/job/211044713/iOS-Developer                                                  2
# https://www.britishjobs.co.uk/job/211045926/Senior-Front-End-Developer                                     2
# https://www.britishjobs.co.uk/job/211044581/Front-End-Developer                                            2
# ...

# %%
valcnt1=valcnt[valcnt > 1]

# %%
valcnt1
# Out:
# https://www.britishjobs.co.uk/job/211047367/Full-Stack-Developer-PHP-Laravel-JavaScript-jQuery         2
# https://www.britishjobs.co.uk/job/211048774/Software-Developer-ASP-NET-MVC                             2
# https://www.britishjobs.co.uk/job/211049250/Senior-JavaScript-Developer-Nottingham-6-Month-Contract    2
# https://www.britishjobs.co.uk/job/207848924/Lead-Nurse                                                 2
# https://www.britishjobs.co.uk/job/211050777/Frontend-Developer                                         2
# https://www.britishjobs.co.uk/job/211040211/Front-End-JavaScript-Developer                             2
# https://www.britishjobs.co.uk/job/211044713/iOS-Developer                                              2
# https://www.britishjobs.co.uk/job/211045926/Senior-Front-End-Developer                                 2
# https://www.britishjobs.co.uk/job/211044581/Front-End-Developer                                        2
# ...

# %%
valcnt1=valcnt1.reset_index()

# %%
valcnt1
# Out:
#                                                 index  JobUrl
# 0   https://www.britishjobs.co.uk/job/211047367/Fu...       2
# 1   https://www.britishjobs.co.uk/job/211048774/So...       2
# 2   https://www.britishjobs.co.uk/job/211049250/Se...       2
# 3   https://www.britishjobs.co.uk/job/207848924/Le...       2
# 4   https://www.britishjobs.co.uk/job/211050777/Fr...       2
# 5   https://www.britishjobs.co.uk/job/211040211/Fr...       2
# 6   https://www.britishjobs.co.uk/job/211044713/iO...       2
# 7   https://www.britishjobs.co.uk/job/211045926/Se...       2
# 8   https://www.britishjobs.co.uk/job/211044581/Fr...       2
# 9   https://www.britishjobs.co.uk/job/209838473/An...       2
# 10  https://www.britishjobs.co.uk/job/211039409/Di...       2
# 11  https://www.britishjobs.co.uk/job/211001719/E-...       2

# %%
valcnt1.columns=['JobUrl','Frequency']

# %%
valcnt1
# Out:
#                                                JobUrl  Frequency
# 0   https://www.britishjobs.co.uk/job/211047367/Fu...          2
# 1   https://www.britishjobs.co.uk/job/211048774/So...          2
# 2   https://www.britishjobs.co.uk/job/211049250/Se...          2
# 3   https://www.britishjobs.co.uk/job/207848924/Le...          2
# 4   https://www.britishjobs.co.uk/job/211050777/Fr...          2
# 5   https://www.britishjobs.co.uk/job/211040211/Fr...          2
# 6   https://www.britishjobs.co.uk/job/211044713/iO...          2
# 7   https://www.britishjobs.co.uk/job/211045926/Se...          2
# 8   https://www.britishjobs.co.uk/job/211044581/Fr...          2
# 9   https://www.britishjobs.co.uk/job/209838473/An...          2
# 10  https://www.britishjobs.co.uk/job/211039409/Di...          2
# 11  https://www.britishjobs.co.uk/job/211001719/E-...          2

# %%
valcnt1 = valcnt1.drop_duplicates()

# %%
dupjoburl=list(valcnt1['JobUrl'])

# %%
print(dupjoburl)
# Out:
# ['https://www.britishjobs.co.uk/job/211047367/Full-Stack-Developer-PHP-Laravel-JavaScript-jQuery', 'https://www.britishjobs.co.uk/job/211048774/Software-Developer-ASP-NET-MVC', 'https://www.britishjobs.co.uk/job/211049250/Senior-JavaScript-Developer-Nottingham-6-Month-Contract', 'https://www.britishjobs.co.uk/job/207848924/Lead-Nurse', 'https://www.britishjobs.co.uk/job/211050777/Frontend-Developer', 'https://www.britishjobs.co.uk/job/211040211/Front-End-JavaScript-Developer', 'https://www.britishjobs.co.uk/job/211044713/iOS-Developer', 'https://www.britishjobs.co.uk/job/211045926/Senior-Front-End-Developer', 'https://www.britishjobs.co.uk/job/211044581/Front-End-Developer', 'https://www.britishjobs.co.uk/job/209838473/Analyst-Programmer', 'https://www.britishjobs.co.uk/job/211039409/Digital-Business-Analyst', 'https://www.britishjobs.co.uk/job/211001719/E-days-Administrator']

# %%
len(dupjoburl)
# Out:
# 12

# %%
data21=df2[~df2.JobUrl.isin(dupjoburl)]

# %%
data21['JobUrl'].value_counts()
# Out:
# https://www.britishjobs.co.uk/job/211118760/Junior-Web-Developer                                            1
# https://www.britishjobs.co.uk/job/211003760/Full-Stack-Engineer                                             1
# https://www.britishjobs.co.uk/job/210941938/Software-Development-Manager                                    1
# https://www.britishjobs.co.uk/job/211042685/GUI-Software-Engineer-C-QT                                      1
# https://www.britishjobs.co.uk/job/211077989/3D-Artist                                                       1
# https://www.britishjobs.co.uk/job/211105558/Group-Digital-Marketing-Executive                               1
# https://www.britishjobs.co.uk/job/211097337/Senior-Designer                                                 1
# https://www.britishjobs.co.uk/job/211025151/Product-Manager                                                 1
# ...

# %%
data21
# Out:
#                                              JobSalary  \
# 0                              £50,000 - £60,000/annum
# 1                                      £375 - £425/day
# 2                                      £350 - £380/day
# 3                                                  NaN
# 4                                 £25,000 - £30,000...
# 5                              £27,600 - £32,800/annum
# 6                                                  NaN
# 7                                                  NaN
# 8                                 £30,000 - £40,000...
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                             £50,000 - £75,000/annum
# 13                  £25,900 - £30,200/annum £26-35,000
# 14                                                 NaN
# 15          £40,000 - £55,000/annum Excellent Benefits
# ...

# %%
data21["isForFreeUsers"]="No"
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data21.to_csv('/Users/Arjun D H/Documents/BritishJobs.csv',header=True)

# %%
data21
# Out:
#                                              JobSalary  \
# 0                              £50,000 - £60,000/annum
# 1                                      £375 - £425/day
# 2                                      £350 - £380/day
# 3                                                  NaN
# 4                                 £25,000 - £30,000...
# 5                              £27,600 - £32,800/annum
# 6                                                  NaN
# 7                                                  NaN
# 8                                 £30,000 - £40,000...
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                             £50,000 - £75,000/annum
# 13                  £25,900 - £30,200/annum £26-35,000
# 14                                                 NaN
# 15          £40,000 - £55,000/annum Excellent Benefits
# ...
