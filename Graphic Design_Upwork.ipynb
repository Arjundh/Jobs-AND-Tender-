# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd
import requests
import numpy as np

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from bs4 import BeautifulSoup
import re
import pandas as pd
import os

# %%
#launch url
all_titles=[]
all_chargetypes=[]
all_explevel=[]
all_section=[]
all_section1=[]
all_section2=[]
all_url=[]

driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')

lisst = ['design-creative/sc/graphic-design']


df1=pd.DataFrame(index=range(0,40000),columns=['JobTitle','JobSalary','JobDescription','JobSkills','LogoUrl','JobUrl'])
df=pd.DataFrame(index=range(0,40000),columns=['JobTitle','JobSalary','LogoUrl','JobUrl','JobDescription','JobSkills'])


for item in lisst:
    category1 = item.split('/sc/')
    
    #url1 = "https://www.upwork.com/o/jobs/browse/c/"+item+"/?page="+str(2)+"&sort=recency"
    #driver.get(url1)
    #driver.find_element_by_xpath("//span[contains(text(),'Last')]").click()
    
    
    #cnt = driver.find_elements_by_xpath("//a[@class='ng-binding']")
    #url3 = cnt[8].text
    #print(url3)
    
    for index in range(278,500):
        print(index)
        #url = "https://www.upwork.com/o/jobs/browse/c/"+item+"/?page="+str(index)+"&sort=recency"
        url = "https://www.upwork.com/search/jobs/c/design-creative/?page="+str(index)+"&q=designer&sort=recency"
        #category1 = item.split('/sc/')
        #df3['Job Category'] = category1[0]
        #df3['Job Sub-Category'] = category1[1]
        driver.get(url)
        driver.implicitly_wait(10)
        section = driver.find_elements_by_xpath("//*[@class='air-card air-card-hover job-tile-responsive ng-scope']")
        sectionurl = driver.find_elements_by_xpath("//a[@class='job-title-link break visited']")
        for i in section:
            all_section.append(i.text)
            all_section1.append(category1[0])
            all_section2.append(category1[1])
        for j in sectionurl:
            all_url.append(j.get_attribute('href'))
#df['Job Category'] = pd.Series(all_section1)
#df['Job Sub-Category'] = pd.Series(all_section2)
#df1['Job Category'] = pd.Series(all_section1)
#df1['Job Sub-Category'] = pd.Series(all_section2)
# Out:
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 430
# 431
# 432
# 433
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# 441
# 442
# 443
# ...

# %%
print(all_url)
# Out:
# ['https://www.upwork.com/job/Video-editor-guru_~01eee1cea4058046d8/', 'https://www.upwork.com/job/Need-design-for-new-company-logo_~0140a724634b941c62/', 'https://www.upwork.com/job/Articulate-Rise-Create-Demo-Courses-Illustrate-basic-features-using-sample-content_~01f84b28f05793bdbb/', 'https://www.upwork.com/job/Pinterest-Manager-amp-Strategist-Needed_~01a1e95f57dff13a7c/', 'https://www.upwork.com/job/Only-Love-brand-promo-flyer_~01eda74bffe3f5355d/', 'https://www.upwork.com/job/creative-calling_~01aa69ab4c2cc8b41f/', 'https://www.upwork.com/job/Logo-for-new-shop-fast-food_~01374efd5f0862543c/', 'https://www.upwork.com/job/Reformat-book-cover-PUB-file-InDesign-and-PDF-file-Clean-existing-design_~0182f089e60340f554/', 'https://www.upwork.com/job/Graphics-pattern-design_~01052e87e9c26945d3/', 'https://www.upwork.com/job/Canva-Specialist_~014dc66a60de4ab08e/', 'https://www.upwork.com/job/Looking-for-someone-with-knowledge-Photoshop-make-infograhics-for-Instagram_~013c802a4631aeeec4/',
# ...

# %%
print(all_section[3])
# Out:
# Pinterest Manager & Strategist Needed
# Hourly ‐ Posted 14d ago
# 10-30 hrs/week
# Hours Needed
# 3 to 6 months
# Duration
# $$
# Intermediate
# Hi, We are a large, established e-commerce store with over 50,000 products looking for a Pinterest social media manager. In this part-time role, your goal will be to help us create a PInterest strategy and then execute on that strategy to help us grow our traffic from this channel. Today, our PInterest traffic accounts for a small amount of our total traffic - something we'd ... more
# Pinterest Marketing Social Media Marketing

# %%
#df=pd.DataFrame(index=range(0,12000),columns=['Job Title','Charge_Type','Rate','Experience_Level','Job_Description','Skills'])
#df1=pd.DataFrame(index=range(0,12000),columns=['Job Title','Charge_Type','Hours_Per_Week','Duration','Experience_Level','Job_Description','Skills'])

for idx,section in enumerate(all_section):
        #'JobTitle','JobSalary','JobDescription','JobSkills','LogoUrl','JobUrl','JobCompanyName','JobLocation'
    
    scn=section.split('\n')
    if('Hourly' in scn[1]):
        df1.iloc[idx,0]=scn[0] #job title
        df1.iloc[idx,1]=scn[2]#chargeing type
        df1.iloc[idx,2]=scn[2] # hours per week
        #df1.iloc[idx,3]=scn[3] # duration
        try:
            df1.iloc[idx,4]=scn[7] #experience level
        except IndexError:
            df1.iloc[idx,4]=np.nan
        try:
            df1.iloc[idx,2]=scn[8] #experience level
        except IndexErro:
            df1.iloc[idx,2]=np.nan
        try:
            df1.iloc[idx,3]=scn[9] #
        except IndexError:
            df1.iloc[idx,3]=np.nan
    elif('Hourly' in scn[0]):
        try:
            df1.iloc[idx,0]=scn[8] #experience level
        except IndexError:
            df1.iloc[idx,0]=np.nan
        
        #df1.iloc[idx,0]=scn[8] #job title
        df1.iloc[idx,0]=scn[0]#chargeing type
        df1.iloc[idx,2]=scn[1] # hours per week
        #df1.iloc[idx,3]=scn[3]
        try:
            df1.iloc[idx,3]=scn[10].split() #
        except IndexError:
            df1.iloc[idx,3]=np.nan
        try:
            df1.iloc[idx,4]=scn[6] #experience level
        except IndexError:
            df1.iloc[idx,4]=np.nan
        try:
            df1.iloc[idx,5]=scn[7] #Job Desc
        except IndexErro:
            df1.iloc[idx,5]=np.nan
        #try:
            #df1.iloc[idx,6]=scn[9].split() #
        #except IndexError:
            #df1.iloc[idx,6]=np.nan
    elif('Fixed' in scn[0]):
        #df1.iloc[idx,0]=scn[8] #job title
        df.iloc[idx,1]=scn[0]#chargeing type
        df.iloc[idx,2]=scn[1] # hours per week
        try:
            df.iloc[idx,4]=scn[5] # duration
        except IndexError:
            df.iloc[idx,4]=np.nan
        try:
            df.iloc[idx,4]=scn[6] #experience level
        except IndexError:
            df.iloc[idx,4]="No Skills Specified"
        try:
            df.iloc[idx,5]=scn[7] #Job Desc
        except IndexError:
            df.iloc[idx,5]=" No Skills Specified"
        #try:
         #   df1.iloc[idx,6]=scn[9].split() #
        #except IndexError:
         #   df1.iloc[idx,6]=np.nan
    else:
        
        df.iloc[idx,0]=scn[0]
        #df.iloc[idx,1]=scn[1].split('-')[0]
        #df.iloc[idx,1]=scn[1]
        df.iloc[idx,1]=scn[2]
        #df.iloc[idx,3]=scn[5]
        try:
            df.iloc[idx,3]=scn[5]
        except IndexError:
            df.iloc[idx,3]=np.nan
        try:
            df.iloc[idx,4]=scn[6]
        except IndexError:
            df.iloc[idx,4]="No Skills Specified"
        try:
            df.iloc[idx,5]=scn[7]
        except IndexError:
            df.iloc[idx,5]="No Skills Specified"

# %%
df = df[df['JobSkills'] != 'NaN']

# %%
df
# Out:
#                                                 JobTitle JobSalary LogoUrl  \
# 0                                                    NaN       NaN     NaN
# 1                                                    NaN       NaN     NaN
# 2      Articulate Rise - Create 5 Demo Courses to Ill...      $300     NaN
# 3                                                    NaN       NaN     NaN
# 4                            Only Love brand/promo flyer      $250     NaN
# 5                                       creative calling      $100     NaN
# 6                         Logo for new shop of fast food        $5     NaN
# 7      Reformat book cover PUB file to InDesign and P...       $50     NaN
# 8                                Graphics pattern design       $15     NaN
# 9                                       Canva Specialist       $10     NaN
# 10     Looking for someone with knowledge in Photosho...        $5     NaN
# ...

# %%
df['JobUrl'] = pd.Series(all_url)
df1['JobUrl'] = pd.Series(all_url)
df['LogoUrl'] = "http://seekvectorlogo.com/wp-content/uploads/2018/01/upwork-vector-logo-small.png"
df1['LogoUrl'] = "http://seekvectorlogo.com/wp-content/uploads/2018/01/upwork-vector-logo-small.png"

# %%
df1['JobSource'] = "upwork"
df['JobSource'] = "upwork"

# %%
df = df.dropna(thresh=4)
df = df.reset_index()

# %%
df.drop(columns=['index'],inplace=True,axis=1)

# %%
df = df[df['JobSkills'] != 'No Skills Specified']

# %%
df
# Out:
#                                                JobTitle JobSalary  \
# 0     Articulate Rise - Create 5 Demo Courses to Ill...      $300
# 1                           Only Love brand/promo flyer      $250
# 2                                      creative calling      $100
# 3                        Logo for new shop of fast food        $5
# 4     Reformat book cover PUB file to InDesign and P...       $50
# 5                               Graphics pattern design       $15
# 6                                      Canva Specialist       $10
# 7     Looking for someone with knowledge in Photosho...        $5
# 8     One-pager PDF presentation (Needed right now/A...      $100
# 10    Need a Logo and Website Creation for my new Ve...    $2,000
# 11                                          Logo Design       $75
# 12                                 3D Airport modelling      $800
# 13                Print Materials for Marketing Mailers      $300
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1045 entries, 0 to 1186
# Data columns (total 7 columns):
# JobTitle          1045 non-null object
# JobSalary         1045 non-null object
# LogoUrl           1045 non-null object
# JobUrl            1045 non-null object
# JobDescription    1045 non-null object
# JobSkills         1045 non-null object
# JobSource         1045 non-null object
# dtypes: object(7)
# memory usage: 65.3+ KB

# %%
df1 = df1.dropna(thresh=4)
df1 = df1.reset_index()

# %%
#df2 = df1.drop(columns=['level_0','index'],axis=1)

# %%
df3 = df1.dropna(thresh=1)
df3 = df3.reset_index()

# %%
df4 = df3.dropna(subset=['JobUrl'])

# %%
df1 = df1[df1 != 'NaN']
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
df4 = df4.dropna(how='any',axis=0)

# %%
df4.columns
# Out:
# Index(['level_0', 'index', 'JobTitle', 'JobSalary', 'JobDescription',
#        'JobSkills', 'LogoUrl', 'JobUrl', 'JobSource'],
#       dtype='object')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 904 entries, 0 to 1032
# Data columns (total 9 columns):
# level_0           904 non-null int64
# index             904 non-null int64
# JobTitle          904 non-null object
# JobSalary         904 non-null object
# JobDescription    904 non-null object
# JobSkills         904 non-null object
# LogoUrl           904 non-null object
# JobUrl            904 non-null object
# JobSource         904 non-null object
# dtypes: int64(2), object(7)
# memory usage: 70.6+ KB

# %%
df4['JobUrl'].nunique()
# Out:
# 901

# %%
df['JobUrl'].nunique()
# Out:
# 1043

# %%
df['JobUrl'].value_counts(ascending=False)
# Out:
# https://www.upwork.com/job/Sleeping-units_~019078199440c7be22/                                                                                2
# https://www.upwork.com/job/Illustration_~01195f73e78be96796/                                                                                  2
# https://www.upwork.com/job/Video-Thumbnail-Designer-needed_~010616f30a790cc986/                                                               1
# https://www.upwork.com/job/Advertisement-Narration-amp-Edits-want-kid-Narration-For-This-Video_~01720032229d5737fa/                           1
# https://www.upwork.com/job/Looking-for-designer-for-social-media-content-ads-and-brand-identity_~014fe650334afb262b/                          1
# https://www.upwork.com/job/Replicate-faded-torn-poster-Playbill_~01e14444b86666bdcf/                                                          1
# ...

# %%
df4
# Out:
#       level_0  index                                           JobTitle  \
# 0           0      0                                  Video editor guru
# 1           1      1               Need a design for a new company logo
# 2           2      3              Pinterest Manager & Strategist Needed
# 3           3     11  Design for a landing webpage and business pres...
# 4           4     13                                              Comic
# 5           5     16                   LOGO Design for Streetwear Brand
# 6           6     19                              Brand Identity Design
# 9           9     29  Building a packaging graphic design for Duct Tape
# 11         11     32  Looking for designer to design minimal logo fo...
# 12         12     36  Graphic Designer for Facebook/Instagram ads fo...
# 13         13     37  designer for emails, postcards, banners - usin...
# 14         14     42                      Slide deck design for Webinar
# ...

# %%
#df1 = df1[df1 != 'NaN']

# %%
df4['JobUrl'].value_counts(ascending=False)
# Out:
# https://www.upwork.com/job/Branding-Marketing-and-Website-development-for-existing-real-estate-investment-company_~014c7b905cefc1b463/      2
# https://www.upwork.com/job/Designer-create-presentation-booklet_~01d32c2903cbc47930/                                                        2
# https://www.upwork.com/job/Podcast-Editor_~0142bd5c98d5326351/                                                                              2
# https://www.upwork.com/job/Shirt-and-Popsocket-Designer_~0189076618464264b7/                                                                1
# https://www.upwork.com/job/Looking-for-web-designer-update-year-old-website_~0130de98fb051bcc67/                                            1
# https://www.upwork.com/job/Augmented-Reality-Object-Specialist-Needed_~01cbaf916a490b1011/                                                  1
# ...

# %%
df4.shape
# Out:
# (904, 9)

# %%
df4.isnull().sum()
# Out:
# level_0           0
# index             0
# JobTitle          0
# JobSalary         0
# JobDescription    0
# JobSkills         0
# LogoUrl           0
# JobUrl            0
# JobSource         0
# dtype: int64

# %%
#if df['JobSkills'] is

df['JobSkills'] = df['JobSkills'].apply(lambda x:', '.join([str(elem) for elem in x]))
#df[['A','B']].apply(lambda x: my_func(x) if(pd.notnull(x[0])) else x, axis = 1)

# %%
df4['JobSkills'] = df4['JobSkills'].apply(lambda x:', '.join([str(elem) for elem in x]))

# %%
df
# Out:
#                                                JobTitle JobSalary  \
# 0     Articulate Rise - Create 5 Demo Courses to Ill...      $300
# 1                           Only Love brand/promo flyer      $250
# 2                                      creative calling      $100
# 3                        Logo for new shop of fast food        $5
# 4     Reformat book cover PUB file to InDesign and P...       $50
# 5                               Graphics pattern design       $15
# 6                                      Canva Specialist       $10
# 7     Looking for someone with knowledge in Photosho...        $5
# 8     One-pager PDF presentation (Needed right now/A...      $100
# 10    Need a Logo and Website Creation for my new Ve...    $2,000
# 11                                          Logo Design       $75
# 12                                 3D Airport modelling      $800
# 13                Print Materials for Marketing Mailers      $300
# ...

# %%
df4
# Out:
#       level_0  index                                           JobTitle  \
# 0           0      0                                  Video editor guru
# 1           1      1               Need a design for a new company logo
# 2           2      3              Pinterest Manager & Strategist Needed
# 3           3     11  Design for a landing webpage and business pres...
# 4           4     13                                              Comic
# 5           5     16                   LOGO Design for Streetwear Brand
# 6           6     19                              Brand Identity Design
# 9           9     29  Building a packaging graphic design for Duct Tape
# 11         11     32  Looking for designer to design minimal logo fo...
# 12         12     36  Graphic Designer for Facebook/Instagram ads fo...
# 13         13     37  designer for emails, postcards, banners - usin...
# 14         14     42                      Slide deck design for Webinar
# ...

# %%
df['JobSkills'] = df['JobSkills'].apply(lambda x:x.replace(', ',''))

# %%
df
# Out:
#                                                JobTitle JobSalary  \
# 0     Articulate Rise - Create 5 Demo Courses to Ill...      $300
# 1                           Only Love brand/promo flyer      $250
# 2                                      creative calling      $100
# 3                        Logo for new shop of fast food        $5
# 4     Reformat book cover PUB file to InDesign and P...       $50
# 5                               Graphics pattern design       $15
# 6                                      Canva Specialist       $10
# 7     Looking for someone with knowledge in Photosho...        $5
# 8     One-pager PDF presentation (Needed right now/A...      $100
# 10    Need a Logo and Website Creation for my new Ve...    $2,000
# 11                                          Logo Design       $75
# 12                                 3D Airport modelling      $800
# 13                Print Materials for Marketing Mailers      $300
# ...

# %%
df4['JobSkills'] = df4['JobSkills'].apply(lambda x:x.replace(', ',''))

# %%
df4
# Out:
#       level_0  index                                           JobTitle  \
# 0           0      0                                  Video editor guru
# 1           1      1               Need a design for a new company logo
# 2           2      3              Pinterest Manager & Strategist Needed
# 3           3     11  Design for a landing webpage and business pres...
# 4           4     13                                              Comic
# 5           5     16                   LOGO Design for Streetwear Brand
# 6           6     19                              Brand Identity Design
# 9           9     29  Building a packaging graphic design for Duct Tape
# 11         11     32  Looking for designer to design minimal logo fo...
# 12         12     36  Graphic Designer for Facebook/Instagram ads fo...
# 13         13     37  designer for emails, postcards, banners - usin...
# 14         14     42                      Slide deck design for Webinar
# ...

# %%
df4 = df4.drop(columns=['index','level_0'])

# %%
df4
# Out:
#                                                JobTitle  \
# 0                                     Video editor guru
# 1                  Need a design for a new company logo
# 2                 Pinterest Manager & Strategist Needed
# 3     Design for a landing webpage and business pres...
# 4                                                 Comic
# 5                      LOGO Design for Streetwear Brand
# 6                                 Brand Identity Design
# 9     Building a packaging graphic design for Duct Tape
# 11    Looking for designer to design minimal logo fo...
# 12    Graphic Designer for Facebook/Instagram ads fo...
# 13    designer for emails, postcards, banners - usin...
# 14                        Slide deck design for Webinar
# 15     Professional Logo needed. Draft already provided
# 16    200+ product pictures for carpets: editing and...
# 18                                          Logo Needed
# 19                                         Illustration
# ...

# %%
df["isForFreeUsers"]="No"

# %%
df4["isForFreeUsers"]="No"

# %%
df4
# Out:
#                                                JobTitle  \
# 0                                     Video editor guru
# 1                  Need a design for a new company logo
# 2                 Pinterest Manager & Strategist Needed
# 3     Design for a landing webpage and business pres...
# 4                                                 Comic
# 5                      LOGO Design for Streetwear Brand
# 6                                 Brand Identity Design
# 9     Building a packaging graphic design for Duct Tape
# 11    Looking for designer to design minimal logo fo...
# 12    Graphic Designer for Facebook/Instagram ads fo...
# 13    designer for emails, postcards, banners - usin...
# 14                        Slide deck design for Webinar
# 15     Professional Logo needed. Draft already provided
# 16    200+ product pictures for carpets: editing and...
# 18                                          Logo Needed
# 19                                         Illustration
# ...

# %%
#df1.to_excel('/Users/dreamsgate/Documents/GraphicsDesign_upwork1.xlsx',header=True)
#df.to_excel('/Users/dreamsgate/Documents/GraphicsDesign_upwork16th_fixed.xlsx',header=True)
df4.to_csv('/Users/Arjun D H/Documents/HourlyJobs2.csv',header=True)
df.to_csv('/Users/Arjun D H/Documents/FixedPriceJobs2.csv',header=True)

# %%
df
# Out:
#                                                JobTitle JobSalary  \
# 0     Articulate Rise - Create 5 Demo Courses to Ill...      $300
# 1                           Only Love brand/promo flyer      $250
# 2                                      creative calling      $100
# 3                        Logo for new shop of fast food        $5
# 4     Reformat book cover PUB file to InDesign and P...       $50
# 5                               Graphics pattern design       $15
# 6                                      Canva Specialist       $10
# 7     Looking for someone with knowledge in Photosho...        $5
# 8     One-pager PDF presentation (Needed right now/A...      $100
# 10    Need a Logo and Website Creation for my new Ve...    $2,000
# 11                                          Logo Design       $75
# 12                                 3D Airport modelling      $800
# 13                Print Materials for Marketing Mailers      $300
# ...
